# %% [markdown]
# # Forecasting Future Electric Energy Production

# %% [markdown]
# Import packages needed for data manipulation, analysis, and visualization.

# %%
import pandas as pd
from matplotlib import pyplot as plt
from statsmodels.tsa.seasonal import seasonal_decompose
from pmdarima.arima import auto_arima

# %% [markdown]
# Read in data on total electricity generation amounts (in kilowatt-hours) per person for different countries over time, then examine and preprocess the data.

# %%
energy_data = pd.read_csv("electricity_generation_total.csv")
energy_data.shape
# Out:
# (65, 33)

# %%
energy_data.head()
# Out:
#       country          1985          1986          1987          1988  \
# 0     Algeria  1.230000e+10  1.300000e+10  1.270000e+10  1.400000e+10
# 1   Argentina  4.530000e+10  4.910000e+10  5.210000e+10  5.310000e+10
# 2   Australia  1.240000e+11  1.300000e+11  1.360000e+11  1.430000e+11
# 3     Austria  4.450000e+10  4.470000e+10  5.050000e+10  4.900000e+10
# 4  Azerbaijan  2.070000e+10  2.150000e+10  2.290000e+10  2.360000e+10
#
#            1989          1990          1991          1992          1993  \
# 0  1.530000e+10  1.610000e+10  1.730000e+10  1.830000e+10  1.940000e+10
# 1  5.090000e+10  5.110000e+10  5.390000e+10  5.650000e+10  6.160000e+10
# 2  1.510000e+11  1.560000e+11  1.580000e+11  1.610000e+11  1.650000e+11
# 3  5.020000e+10  5.040000e+10  5.150000e+10  5.120000e+10  5.270000e+10
# 4  2.330000e+10  2.320000e+10  2.340000e+10  1.970000e+10  1.910000e+10
#
#        ...               2007          2008          2009          2010  \
# 0      ...       3.730000e+10  4.020000e+10  4.310000e+10  4.570000e+10
# 1      ...       1.150000e+11  1.290000e+11  1.300000e+11  1.330000e+11
# 2      ...       2.430000e+11  2.450000e+11  2.500000e+11  2.510000e+11
# 3      ...       6.490000e+10  6.690000e+10  6.910000e+10  7.110000e+10
# 4      ...       2.180000e+10  2.160000e+10  1.890000e+10  1.870000e+10
#
#            2011          2012          2013          2014          2015  \
# 0  5.310000e+10  5.740000e+10  5.990000e+10  6.420000e+10  6.880000e+10
# 1  1.290000e+11  1.360000e+11  1.400000e+11  1.420000e+11  1.450000e+11
# 2  2.560000e+11  2.510000e+11  2.500000e+11  2.470000e+11  2.530000e+11
# 3  6.590000e+10  7.240000e+10  6.800000e+10  6.510000e+10  6.490000e+10
# 4  2.030000e+10  2.300000e+10  2.340000e+10  2.470000e+10  2.470000e+10
#
#            2016
# 0  7.020000e+10
# 1  1.470000e+11
# 2  2.570000e+11
# 3  6.760000e+10
# 4  2.500000e+10
#
# [5 rows x 33 columns]

# %%
energy_data.tail()
# Out:
#            country          1985          1986          1987          1988  \
# 60  United Kingdom  2.980000e+11  3.010000e+11  3.020000e+11  3.090000e+11
# 61   United States  2.630000e+12  2.650000e+12  2.740000e+12  2.880000e+12
# 62      Uzbekistan  4.790000e+10  5.220000e+10  5.480000e+10  5.060000e+10
# 63       Venezuela  4.730000e+10  5.010000e+10  5.410000e+10  5.820000e+10
# 64         Vietnam  5.070000e+09  5.680000e+09  6.210000e+09  6.960000e+09
#
#             1989          1990          1991          1992          1993  \
# 60  3.150000e+11  3.200000e+11  3.230000e+11  3.210000e+11  3.230000e+11
# 61  3.160000e+12  3.230000e+12  3.270000e+12  3.280000e+12  3.400000e+12
# 62  5.590000e+10  5.630000e+10  5.420000e+10  5.110000e+10  4.870000e+10
# 63  5.760000e+10  5.930000e+10  6.330000e+10  6.740000e+10  6.940000e+10
# 64  7.950000e+09  8.680000e+09  9.210000e+09  9.710000e+09  1.070000e+10
#
#         ...               2007          2008          2009          2010  \
# 60      ...       3.970000e+11  3.890000e+11  3.770000e+11  3.820000e+11
# 61      ...       4.430000e+12  4.390000e+12  4.210000e+12  4.390000e+12
# 62      ...       4.900000e+10  5.010000e+10  5.000000e+10  5.170000e+10
# 63      ...       1.140000e+11  1.190000e+11  1.250000e+11  1.170000e+11
# 64      ...       6.410000e+10  7.100000e+10  8.060000e+10  9.170000e+10
#
#             2011          2012          2013          2014          2015  \
# 60  3.670000e+11  3.640000e+11  3.580000e+11  3.380000e+11  3.390000e+11
# 61  4.360000e+12  4.310000e+12  4.330000e+12  4.360000e+12  4.350000e+12
# 62  5.240000e+10  5.250000e+10  5.420000e+10  5.560000e+10  5.760000e+10
# 63  1.230000e+11  1.280000e+11  1.280000e+11  1.100000e+11  1.280000e+11
# 64  1.020000e+11  1.150000e+11  1.240000e+11  1.420000e+11  1.600000e+11
#
#             2016
# 60  3.390000e+11
# 61  4.350000e+12
# 62  5.890000e+10
# 63  1.160000e+11
# 64  1.760000e+11
#
# [5 rows x 33 columns]

# %%
us_energy_data = energy_data[energy_data["country"] == "United States"]
us_energy_data
# Out:
#           country          1985          1986          1987          1988  \
# 61  United States  2.630000e+12  2.650000e+12  2.740000e+12  2.880000e+12
#
#             1989          1990          1991          1992          1993  \
# 61  3.160000e+12  3.230000e+12  3.270000e+12  3.280000e+12  3.400000e+12
#
#         ...               2007          2008          2009          2010  \
# 61      ...       4.430000e+12  4.390000e+12  4.210000e+12  4.390000e+12
#
#             2011          2012          2013          2014          2015  \
# 61  4.360000e+12  4.310000e+12  4.330000e+12  4.360000e+12  4.350000e+12
#
#             2016
# 61  4.350000e+12
#
# [1 rows x 33 columns]

# %%
us_energy_data.set_index('country', inplace = True)

# %%
us_energy_data
# Out:
#                        1985          1986          1987          1988  \
# country
# United States  2.630000e+12  2.650000e+12  2.740000e+12  2.880000e+12
#
#                        1989          1990          1991          1992  \
# country
# United States  3.160000e+12  3.230000e+12  3.270000e+12  3.280000e+12
#
#                        1993          1994      ...               2007  \
# country                                        ...
# United States  3.400000e+12  3.460000e+12      ...       4.430000e+12
#
#                        2008          2009          2010          2011  \
# country
# United States  4.390000e+12  4.210000e+12  4.390000e+12  4.360000e+12
#
#                        2012          2013          2014          2015  \
# country
# United States  4.310000e+12  4.330000e+12  4.360000e+12  4.350000e+12
#
#                        2016
# country
# United States  4.350000e+12
#
# [1 rows x 32 columns]

# %%
years = us_energy_data.columns.tolist()
years_with_last_day = [str(year) for year in years]
us_energy_data.columns = pd.to_datetime(years_with_last_day)

# %%
us_energy_data
# Out:
#                  1985-01-01    1986-01-01    1987-01-01    1988-01-01  \
# country
# United States  2.630000e+12  2.650000e+12  2.740000e+12  2.880000e+12
#
#                  1989-01-01    1990-01-01    1991-01-01    1992-01-01  \
# country
# United States  3.160000e+12  3.230000e+12  3.270000e+12  3.280000e+12
#
#                  1993-01-01    1994-01-01      ...         2007-01-01  \
# country                                        ...
# United States  3.400000e+12  3.460000e+12      ...       4.430000e+12
#
#                  2008-01-01    2009-01-01    2010-01-01    2011-01-01  \
# country
# United States  4.390000e+12  4.210000e+12  4.390000e+12  4.360000e+12
#
#                  2012-01-01    2013-01-01    2014-01-01    2015-01-01  \
# country
# United States  4.310000e+12  4.330000e+12  4.360000e+12  4.350000e+12
#
#                  2016-01-01
# country
# United States  4.350000e+12
#
# [1 rows x 32 columns]

# %%
us_energy_time_series_data = us_energy_data.T
us_energy_time_series_data.columns = ["United States"]
us_energy_time_series_data.head()
# Out:
#             United States
# 1985-01-01   2.630000e+12
# 1986-01-01   2.650000e+12
# 1987-01-01   2.740000e+12
# 1988-01-01   2.880000e+12
# 1989-01-01   3.160000e+12

# %% [markdown]
# Perform a decomposition of the time series data

# %%
decomp = seasonal_decompose(us_energy_time_series_data)
decomp_fig = decomp.plot()

# %% [markdown]
# Have the arima model automatically build itself by selecting a range of models with varying parameters and then seeing how their Akaike information criterion (AIC) scores compare to each other. The model that has the best combination of goodness of fit and simplicity will have the best (lowest) AIC score, and this model will be used to forecast future energy production levels.

# %%
model = auto_arima(us_energy_time_series_data, start_p=1, start_q=1,
                           max_p=20, max_q=20, m=12,
                           start_P=0, seasonal=True,
                           d=1, D=1, trace=True,
                           error_action='ignore',  
                           suppress_warnings=True, 
                           stepwise=True)
# Out:
# Fit ARIMA: order=(1, 1, 1) seasonal_order=(0, 1, 1, 10); AIC=nan, BIC=nan, Fit time=nan seconds
# Fit ARIMA: order=(0, 1, 0) seasonal_order=(0, 1, 0, 10); AIC=1126.750, BIC=1128.839, Fit time=0.031 seconds
# Fit ARIMA: order=(1, 1, 0) seasonal_order=(1, 1, 0, 10); AIC=1128.615, BIC=1132.793, Fit time=0.085 seconds
# Fit ARIMA: order=(0, 1, 1) seasonal_order=(0, 1, 1, 10); AIC=nan, BIC=nan, Fit time=nan seconds
# Fit ARIMA: order=(0, 1, 0) seasonal_order=(1, 1, 0, 10); AIC=1128.653, BIC=1131.787, Fit time=0.053 seconds
# Fit ARIMA: order=(0, 1, 0) seasonal_order=(0, 1, 1, 10); AIC=nan, BIC=nan, Fit time=nan seconds
# Fit ARIMA: order=(0, 1, 0) seasonal_order=(1, 1, 1, 10); AIC=nan, BIC=nan, Fit time=nan seconds
# Fit ARIMA: order=(1, 1, 0) seasonal_order=(0, 1, 0, 10); AIC=1126.874, BIC=1130.008, Fit time=0.055 seconds
# Fit ARIMA: order=(0, 1, 1) seasonal_order=(0, 1, 0, 10); AIC=1127.709, BIC=1130.843, Fit time=0.036 seconds
# Fit ARIMA: order=(1, 1, 1) seasonal_order=(0, 1, 0, 10); AIC=1127.085, BIC=1131.263, Fit time=0.133 seconds
# Total fit time: 0.414 seconds

# %%
model.aic()
# Out:
# 1126.7495970769116

# %% [markdown]
# ## Cross-Validation

# %%
us_energy_time_series_data
# Out:
#             United States
# 1985-01-01   2.630000e+12
# 1986-01-01   2.650000e+12
# 1987-01-01   2.740000e+12
# 1988-01-01   2.880000e+12
# 1989-01-01   3.160000e+12
# 1990-01-01   3.230000e+12
# 1991-01-01   3.270000e+12
# 1992-01-01   3.280000e+12
# 1993-01-01   3.400000e+12
# 1994-01-01   3.460000e+12
# 1995-01-01   3.570000e+12
# 1996-01-01   3.660000e+12
# 1997-01-01   3.720000e+12
# 1998-01-01   3.860000e+12
# 1999-01-01   3.940000e+12
# 2000-01-01   4.050000e+12
# 2001-01-01   3.980000e+12
# 2002-01-01   4.110000e+12
# 2003-01-01   4.140000e+12
# 2004-01-01   4.230000e+12
# 2005-01-01   4.320000e+12
# 2006-01-01   4.330000e+12
# 2007-01-01   4.430000e+12
# 2008-01-01   4.390000e+12
# 2009-01-01   4.210000e+12
# 2010-01-01   4.390000e+12
# 2011-01-01   4.360000e+12
# 2012-01-01   4.310000e+12
# 2013-01-01   4.330000e+12
# 2014-01-01   4.360000e+12
# 2015-01-01   4.350000e+12
# 2016-01-01   4.350000e+12

# %%
us_energy_time_series_data.shape
# Out:
# (32, 1)

# %%
training_data = us_energy_time_series_data.iloc[0:27,]
print(training_data.size)
training_data
# Out:
# 27
#             United States
# 1985-01-01   2.630000e+12
# 1986-01-01   2.650000e+12
# 1987-01-01   2.740000e+12
# 1988-01-01   2.880000e+12
# 1989-01-01   3.160000e+12
# 1990-01-01   3.230000e+12
# 1991-01-01   3.270000e+12
# 1992-01-01   3.280000e+12
# 1993-01-01   3.400000e+12
# 1994-01-01   3.460000e+12
# 1995-01-01   3.570000e+12
# 1996-01-01   3.660000e+12
# 1997-01-01   3.720000e+12
# 1998-01-01   3.860000e+12
# 1999-01-01   3.940000e+12
# 2000-01-01   4.050000e+12
# 2001-01-01   3.980000e+12
# 2002-01-01   4.110000e+12
# 2003-01-01   4.140000e+12
# 2004-01-01   4.230000e+12
# 2005-01-01   4.320000e+12
# 2006-01-01   4.330000e+12
# 2007-01-01   4.430000e+12
# 2008-01-01   4.390000e+12
# 2009-01-01   4.210000e+12
# 2010-01-01   4.390000e+12
# 2011-01-01   4.360000e+12

# %%
test_data = us_energy_time_series_data.iloc[27:,]
print(test_data.size)
test_data
# Out:
# 5
#             United States
# 2012-01-01   4.310000e+12
# 2013-01-01   4.330000e+12
# 2014-01-01   4.360000e+12
# 2015-01-01   4.350000e+12
# 2016-01-01   4.350000e+12

# %%
model.fit(training_data)
# Out:
# ARIMA(callback=None, disp=0, maxiter=50, method=None, order=(0, 1, 0),
#    out_of_sample_size=0, scoring='mse', scoring_args={},
#    seasonal_order=(0, 1, 0, 10), solver='lbfgs', start_params=None,
#    suppress_warnings=True, transparams=True, trend=None,
#    with_intercept=True)

# %%
forecast = model.predict(n_periods = 5)

# %%
forecast
# Out:
# array([4.455e+12, 4.450e+12, 4.505e+12, 4.560e+12, 4.535e+12])

# %%
electric_energy_forecast = pd.DataFrame(forecast, index = test_data.index, columns = ["Electricity Production Forecast"])

# %%
electric_energy_forecast
# Out:
#             Electricity Production Forecast
# 2012-01-01                     4.455000e+12
# 2013-01-01                     4.450000e+12
# 2014-01-01                     4.505000e+12
# 2015-01-01                     4.560000e+12
# 2016-01-01                     4.535000e+12

# %%
test_data
# Out:
#             United States
# 2012-01-01   4.310000e+12
# 2013-01-01   4.330000e+12
# 2014-01-01   4.360000e+12
# 2015-01-01   4.350000e+12
# 2016-01-01   4.350000e+12

# %%
side_by_side = pd.concat([electric_energy_forecast, test_data], axis=1)
side_by_side.plot()
