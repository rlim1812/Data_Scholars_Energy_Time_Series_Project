# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import zipfile

plt.style.use('fivethirtyeight') # Use plt.style.available to see more styles
sns.set()
sns.set_context("talk")
# %matplotlib inline

# %% [markdown]
# #### Aim
# Examine the rate of electricity generation in different countries over time

# %%
elec = pd.read_csv("electricity_generation_per_person.csv")

# %%
elec.head()
# Out:
#       country    1985    1986    1987    1988    1989    1990    1991  1992  \
# 0     Algeria   544.0   559.0   532.0   568.0   607.0   621.0   653.0   673
# 1   Argentina  1490.0  1590.0  1660.0  1670.0  1580.0  1560.0  1620.0  1680
# 2   Australia  7860.0  8100.0  8360.0  8670.0  9020.0  9130.0  9150.0  9230
# 3     Austria  5850.0  5860.0  6610.0  6400.0  6530.0  6530.0  6620.0  6540
# 4  Azerbaijan  3110.0  3180.0  3320.0  3360.0  3270.0  3200.0  3170.0  2630
#
#    1993  ...     2007   2008   2009   2010   2011   2012   2013   2014   2015  \
# 0   699  ...     1090   1150   1220   1270   1440   1530   1560   1640   1730
# 1  1810  ...     2880   3190   3180   3210   3110   3230   3280   3290   3350
# 2  9350  ...    11600  11500  11500  11300  11400  11000  10800  10500  10600
# 3  6670  ...     7800   8030   8250   8450   7780   8500   7930   7540   7480
# 4  2520  ...     2500   2450   2110   2070   2220   2480   2490   2600   2570
#
#     2016
# 0   1730
# 1   3350
# 2  10600
# 3   7760
# 4   2570
#
# [5 rows x 33 columns]

# %%
#make country categorical variable into numerical value
#elec['country'] = pd.Categorical(elec['country'])

# %%
len(elec.loc[0].values[1:])
# Out:
# 32

# %%
len(np.arange(1985,2016))
# Out:
# 31

# %% [markdown]
# ### 1st attempt to plot Electricity Generated vs Time

# %%
#time vs electricity generation
for i in range(len(elec)):
    plt.scatter(np.arange(1985, 2017), elec.loc[i].values[1:])
plt.title('Electricity Generation for Each Country Over Time')
plt.xlabel('time (years)')
plt.ylabel('Electricity Generated (kilowatt/hr)');

# %% [markdown]
# ### 2nd Attempt: Construct Hans Rosling Plot

# %%
pop = pd.read_csv('urban_population.csv')
pop.head()
# Out:
#        country       1960       1961       1962       1963       1964  \
# 0  Afghanistan   756000.0   796000.0   839000.0   884000.0   933000.0
# 1      Albania   494000.0   514000.0   531000.0   548000.0   565000.0
# 2      Algeria  3390000.0  3630000.0  3880000.0  4150000.0  4440000.0
# 3      Andorra     7840.0     8770.0     9750.0    10800.0    11900.0
# 4       Angola   589000.0   621000.0   657000.0   695000.0   735000.0
#
#         1965       1966       1967       1968     ...          2008      2009  \
# 0   984000.0  1040000.0  1100000.0  1160000.0     ...       6360000   6590000
# 1   582000.0   599000.0   617000.0   636000.0     ...       1470000   1500000
# 2  4750000.0  5040000.0  5210000.0  5380000.0     ...      23000000  23700000
# 3    13100.0    14300.0    15500.0    16800.0     ...         74600     75100
# 4   776000.0   818000.0   862000.0   909000.0     ...      12700000  13300000
#
#        2010      2011        2012        2013        2014        2015  \
# 0   6840000   7110000   7420000.0   7730000.0   8050000.0   8370000.0
# 1   1520000   1550000   1580000.0   1600000.0   1630000.0   1650000.0
# 2  24400000  25100000  25900000.0  26700000.0  27500000.0  28200000.0
# 3     75000     74300     73100.0     71500.0     70100.0     68900.0
# 4  14000000  14700000  15400000.0  16100000.0  16900000.0  17700000.0
#
#          2016        2017
# 0   8670000.0   8970000.0
# 1   1680000.0   1710000.0
# 2  29000000.0  29800000.0
# 3     68200.0     67800.0
# 4  18500000.0  19300000.0
#
# [5 rows x 59 columns]

# %%
#select only from years 1985-2016
pop = pop.drop(pop.columns[np.arange(25)+1], axis = 1)
len(pop)
# Out:
# 194

# %%
len(elec)
# Out:
# 65

# %%
#year_x = electricity generated
#year_y = population
#merged on electricity generated countries data to get population for only countries in that data
merged = elec.merge(pop, how = 'left', left_on = 'country', right_on = 'country').set_index('country')
merged.head()
# Out:
#             1985_x  1986_x  1987_x  1988_x  1989_x  1990_x  1991_x  1992_x  \
# country
# Algeria      544.0   559.0   532.0   568.0   607.0   621.0   653.0     673
# Argentina   1490.0  1590.0  1660.0  1670.0  1580.0  1560.0  1620.0    1680
# Australia   7860.0  8100.0  8360.0  8670.0  9020.0  9130.0  9150.0    9230
# Austria     5850.0  5860.0  6610.0  6400.0  6530.0  6530.0  6620.0    6540
# Azerbaijan  3110.0  3180.0  3320.0  3360.0  3270.0  3200.0  3170.0    2630
#
#             1993_x  1994_x     ...        2008_y    2009_y    2010_y  \
# country                        ...
# Algeria        699   701.0     ...      23000000  23700000  24400000
# Argentina     1810  1890.0     ...      36600000  37000000  37500000
# Australia     9350  9510.0     ...      18000000  18500000  18800000
# Austria       6670  6710.0     ...       4820000   4810000   4800000
# Azerbaijan    2520  2290.0     ...       4640000   4760000   4840000
#
#               2011_y      2012_y      2013_y      2014_y      2015_y  \
# country
# Algeria     25100000  25900000.0  26700000.0  27500000.0  28200000.0
# Argentina   37900000  38400000.0  38800000.0  39300000.0  39700000.0
# Australia   19100000  19400000.0  19800000.0  20100000.0  20400000.0
# Austria      4790000   4820000.0   4860000.0   4920000.0   4990000.0
# Azerbaijan   4920000   5010000.0   5100000.0   5190000.0   5280000.0
#
#                 2016_y        2017
# country
# Algeria     29000000.0  29800000.0
# Argentina   40200000.0  40600000.0
# Australia   20800000.0  21100000.0
# Austria      5060000.0   5120000.0
# Azerbaijan   5370000.0   5460000.0
#
# [5 rows x 65 columns]

# %%
pop_vals = merged.loc[:, '1985_y': '2016_y']
pop_vals.head()
# Out:
#                 1985_y      1986_y      1987_y      1988_y      1989_y  \
# country
# Algeria     10800000.0  11400000.0  11900000.0  12400000.0  13000000.0
# Argentina   25800000.0  26400000.0  26900000.0  27400000.0  27900000.0
# Australia   13500000.0  13700000.0  13900000.0  14100000.0  14400000.0
# Austria      4860000.0   4850000.0   4830000.0   4820000.0   4820000.0
# Azerbaijan   3570000.0   3640000.0   3720000.0   3790000.0   3850000.0
#
#               1990_y    1991_y      1992_y      1993_y      1994_y  \
# country
# Algeria     13500000  14000000  14600000.0  15100000.0  15700000.0
# Argentina   28500000  29000000  29500000.0  29900000.0  30400000.0
# Australia   14600000  14800000  14900000.0  15000000.0  15200000.0
# Austria      4830000   4860000   4890000.0   4910000.0   4910000.0
# Azerbaijan   3850000   3890000   3920000.0   3960000.0   3990000.0
#
#                ...        2007_y    2008_y    2009_y    2010_y    2011_y  \
# country        ...
# Algeria        ...      22400000  23000000  23700000  24400000  25100000
# Argentina      ...      36100000  36600000  37000000  37500000  37900000
# Australia      ...      17700000  18000000  18500000  18800000  19100000
# Austria        ...       4830000   4820000   4810000   4800000   4790000
# Azerbaijan     ...       4530000   4640000   4760000   4840000   4920000
#
#                 2012_y      2013_y      2014_y      2015_y      2016_y
# country
# Algeria     25900000.0  26700000.0  27500000.0  28200000.0  29000000.0
# Argentina   38400000.0  38800000.0  39300000.0  39700000.0  40200000.0
# Australia   19400000.0  19800000.0  20100000.0  20400000.0  20800000.0
# Austria      4820000.0   4860000.0   4920000.0   4990000.0   5060000.0
# Azerbaijan   5010000.0   5100000.0   5190000.0   5280000.0   5370000.0
#
# [5 rows x 32 columns]

# %%
elec_vals = merged.loc[:, '1985_x': '2016_x']
elec_vals.head()
# Out:
#             1985_x  1986_x  1987_x  1988_x  1989_x  1990_x  1991_x  1992_x  \
# country
# Algeria      544.0   559.0   532.0   568.0   607.0   621.0   653.0     673
# Argentina   1490.0  1590.0  1660.0  1670.0  1580.0  1560.0  1620.0    1680
# Australia   7860.0  8100.0  8360.0  8670.0  9020.0  9130.0  9150.0    9230
# Austria     5850.0  5860.0  6610.0  6400.0  6530.0  6530.0  6620.0    6540
# Azerbaijan  3110.0  3180.0  3320.0  3360.0  3270.0  3200.0  3170.0    2630
#
#             1993_x  1994_x   ...    2007_x  2008_x  2009_x  2010_x  2011_x  \
# country                      ...
# Algeria        699   701.0   ...      1090    1150    1220    1270    1440
# Argentina     1810  1890.0   ...      2880    3190    3180    3210    3110
# Australia     9350  9510.0   ...     11600   11500   11500   11300   11400
# Austria       6670  6710.0   ...      7800    8030    8250    8450    7780
# Azerbaijan    2520  2290.0   ...      2500    2450    2110    2070    2220
#
#             2012_x  2013_x  2014_x  2015_x  2016_x
# country
# Algeria       1530    1560    1640    1730    1730
# Argentina     3230    3280    3290    3350    3350
# Australia    11000   10800   10500   10600   10600
# Austria       8500    7930    7540    7480    7760
# Azerbaijan    2480    2490    2600    2570    2570
#
# [5 rows x 32 columns]

# %%
set_x = pop_vals.iloc[0]
set_x.head()
# Out:
# 1985_y    10800000.0
# 1986_y    11400000.0
# 1987_y    11900000.0
# 1988_y    12400000.0
# 1989_y    13000000.0
# Name: Algeria, dtype: float64

# %%
c=merged.index
np.array(c)
# Out:
# array(['Algeria', 'Argentina', 'Australia', 'Austria', 'Azerbaijan',
#        'Bangladesh', 'Belarus', 'Belgium', 'Brazil', 'Bulgaria', 'Canada',
#        'Chile', 'China', 'Colombia', 'Czech Republic', 'Denmark',
#        'Ecuador', 'Egypt', 'Finland', 'France', 'Germany', 'Greece',
#        'Hungary', 'India', 'Indonesia', 'Iran', 'Ireland', 'Israel',
#        'Italy', 'Japan', 'Kazakhstan', 'Kuwait', 'Lithuania', 'Malaysia',
#        'Mexico', 'Netherlands', 'New Zealand', 'Norway', 'Pakistan',
#        'Peru', 'Philippines', 'Poland', 'Portugal', 'Qatar', 'Romania',
#        'Russia', 'Saudi Arabia', 'Singapore', 'Slovak Republic',
#        'South Africa', 'South Korea', 'Spain', 'Sweden', 'Switzerland',
#        'Thailand', 'Trinidad and Tobago', 'Turkey', 'Turkmenistan',
#        'Ukraine', 'United Arab Emirates', 'United Kingdom',
#        'United States', 'Uzbekistan', 'Venezuela', 'Vietnam'],
#       dtype=object)

# %%
pop_vals.iloc[:, 0].head()
# Out:
# country
# Algeria       10800000.0
# Argentina     25800000.0
# Australia     13500000.0
# Austria        4860000.0
# Azerbaijan     3570000.0
# Name: 1985_y, dtype: float64

# %%
for i in range(len(pop_vals)):
    for j in range(len(elec_vals)):
        set_x = pop_vals.iloc[i]
        set_y = elec_vals.iloc[j]
        plt.scatter(set_x, set_y, s = 1, cmap = 'Accent', alpha = 0.6, linewidth = 2)
        
plt.xlabel("Population")
plt.ylabel("Electricity Generation per Person")
plt.title("Electricity Generation per Person in Each Country");
# Out:
# Text(0.5, 1.0, 'Electricity Generation per Person in Each Country')

# %%
convert -delay 80 Gapminder*.png animated_gapminder.gif
